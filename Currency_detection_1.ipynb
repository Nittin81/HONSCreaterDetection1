# %% [markdown]
# <a href="https://colab.research.google.com/github/Nittin81/HONSCreaterDetection1/blob/main/Currency_detection_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from PIL import Image
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Input, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras import layers
from keras.utils import plot_model

# %%
# !mkdir ./train
# !mkdir ./test
# !mkdir ./valid

# %%
# !unzip -o /content/test/test.zip -d ./
print("train.zip unzipped into existing ./train folder.")
# !unzip -o /content/train/train.zip -d ./
print("train.zip unzipped into existing ./train folder.")
# !unzip -o /content/valid/valid.zip -d ./
print("train.zip unzipped into existing ./train folder.")
# Out:
# Archive:  /content/test/test.zip
#    creating: ./test/1/
#   inflating: ./test/1/1.100.jpg
#   inflating: ./test/1/1.22.jpg
#   inflating: ./test/1/1.24.jpg
#   inflating: ./test/1/1.26.jpg
#   inflating: ./test/1/1.28.jpg
#   inflating: ./test/1/1.40.jpg
#   inflating: ./test/1/1.41.jpg
#   inflating: ./test/1/1.42.jpg
#   inflating: ./test/1/1.5.jpg
#   inflating: ./test/1/1.56.jpg
#   inflating: ./test/1/1.59.jpg
#   inflating: ./test/1/1.6.jpg
#   inflating: ./test/1/1.65.jpg
#   inflating: ./test/1/1.7.jpg
#   inflating: ./test/1/1.70.jpg
#   inflating: ./test/1/1.74.jpg
#   inflating: ./test/1/1.78.jpg
#   inflating: ./test/1/1.79.jpg
#   inflating: ./test/1/1.84.jpg
#   inflating: ./test/1/1.97.jpg
#    creating: ./test/10/
#   inflating: ./test/10/10.10.jpg
#   inflating: ./test/10/10.100.jpg
#   inflating: ./test/10/10.11.jpg
#   inflating: ./test/10/10.14.jpg
#   inflating: ./test/10/10.25.JPG
#   inflating: ./test/10/10.26.JPG
#   inflating: ./test/10/10.28.jpg
#   inflating: ./test/10/10.37.jpg
#   inflating: ./test/10/10.38.jpg
#   inflating: ./test/10/10.4.jpg
#   inflating: ./test/10/10.46.jpg
#   inflating: ./test/10/10.50.jpg
#   inflating: ./test/10/10.51.jpg
#   inflating: ./test/10/10.60.jpg
#   inflating: ./test/10/10.64.jpg
#   inflating: ./test/10/10.69.jpg
#   inflating: ./test/10/10.70.jpg
#   inflating: ./test/10/10.79.jpg
#   inflating: ./test/10/10.93.jpg
#   inflating: ./test/10/10.95.jpg
#   inflating: ./test/10/IMG-20231217-WA0185.jpg
#   inflating: ./test/10/IMG-20231217-WA0359.jpg
#   inflating: ./test/10/IMG-20231217-WA0367.jpg
#   inflating: ./test/10/IMG-20231217-WA0403.jpg
#   inflating: ./test/10/IMG-20231217-WA0439.jpg
#   inflating: ./test/10/IMG-20231217-WA0440.jpg
#   inflating: ./test/10/IMG-20231217-WA0441.jpg
#   inflating: ./test/10/IMG-20231217-WA0444.jpg
#   inflating: ./test/10/IMG-20231217-WA0445.jpg
#   inflating: ./test/10/IMG-20231217-WA0446.jpg
#   inflating: ./test/10/IMG_20231217_040334.jpg
#   inflating: ./test/10/IMG_20231217_040339.jpg
#   inflating: ./test/10/IMG_20231217_040341.jpg
#   inflating: ./test/10/IMG_20231217_040458.jpg
#   inflating: ./test/10/IMG_20231217_040912.jpg
#   inflating: ./test/5/IMG_20231217_040056.jpg
#    creating: ./test/50/
#   inflating: ./test/50/50.1.jpg
#   inflating: ./test/50/50.11.jpg
#   inflating: ./test/50/50.12.jpg
#   inflating: ./test/50/50.14.jpg
#   inflating: ./test/50/50.25.jpg
#   inflating: ./test/50/50.29.jpg
#   inflating: ./test/50/50.4.jpg
#   inflating: ./test/50/50.48.jpg
#   inflating: ./test/50/50.49.jpg
#   inflating: ./test/50/50.62.jpg
#   inflating: ./test/50/50.64.jpg
#   inflating: ./test/50/50.65.jpg
#   inflating: ./test/50/50.66.jpg
#   inflating: ./test/50/50.69.jpg
#   inflating: ./test/50/50.7(1).jpg
#   inflating: ./test/50/50.71.jpg
#   inflating: ./test/50/50.72.jpg
#   inflating: ./test/50/50.77.jpg
#   inflating: ./test/50/50.79.jpg
#   inflating: ./test/50/50.88.jpg
#   inflating: ./test/50/IMG-20231217-WA0454.jpg
#   inflating: ./test/50/IMG-20231217-WA0455.jpg
#   inflating: ./test/50/IMG-20231217-WA0456.jpg
#   inflating: ./test/50/IMG-20231217-WA0457.jpg
#   inflating: ./test/50/IMG-20231217-WA0459.jpg
#   inflating: ./test/50/IMG-20231217-WA0460.jpg
#   inflating: ./test/50/IMG-20231217-WA0461.jpg
#   inflating: ./test/50/IMG-20231217-WA0462.jpg
#   inflating: ./test/50/IMG-20231217-WA0463.jpg
#   inflating: ./test/50/IMG-20231217-WA0464.jpg
#   inflating: ./test/50/IMG-20231217-WA0465.jpg
#   inflating: ./test/50/IMG-20231217-WA0466.jpg
#   inflating: ./test/50/IMG-20231217-WA0467.jpg
#   inflating: ./test/50/IMG-20231217-WA0468.jpg
#   inflating: ./test/50/IMG-20231217-WA0523.jpg
# train.zip unzipped into existing ./train folder.
# Archive:  /content/train/train.zip
#    creating: ./train/1/
#   inflating: ./train/1/1.1.jpg
#   inflating: ./train/1/1.10.jpg
#   inflating: ./train/1/1.101.jpg
#   inflating: ./train/1/1.11.jpg
#   inflating: ./train/1/1.13.jpg
#   inflating: ./train/1/1.14.jpg
#   inflating: ./train/1/1.15.jpg
#   inflating: ./train/1/1.16.jpg
#   inflating: ./train/1/1.18.jpg
#   inflating: ./train/1/1.19.jpg
#   inflating: ./train/1/1.2.jpg
#   inflating: ./train/1/1.20.jpg
#   inflating: ./train/1/1.21.jpg
#   inflating: ./train/1/1.23.jpg
#   inflating: ./train/1/1.25.jpg
#   inflating: ./train/1/1.27.jpg
#   inflating: ./train/1/1.29.jpg
#   inflating: ./train/1/1.30.jpg
#   inflating: ./train/1/1.31.jpg
#   inflating: ./train/1/1.32.jpg
#   inflating: ./train/1/1.34.jpg
#   inflating: ./train/1/1.35.jpg
#   inflating: ./train/1/1.36.jpg
#   inflating: ./train/1/1.37.jpg
#   inflating: ./train/1/1.38.jpg
#   inflating: ./train/1/1.39.jpg
#   inflating: ./train/1/1.43.jpg
#   inflating: ./train/1/1.44.jpg
#   inflating: ./train/1/1.45.jpg
#   inflating: ./train/10 (new)/cat-5098930_1280.jpg
#   inflating: ./train/10 (new)/cat-8438334_640.jpg
#   inflating: ./train/10 (new)/checkmate-1511866_640.jpg
#   inflating: ./train/10 (new)/child-2916861_640.jpg
#   inflating: ./train/10 (new)/child-817371_640.jpg
#   inflating: ./train/10 (new)/church-8444287_640.jpg
#   inflating: ./train/10 (new)/clouds-2329680_640.jpg
#   inflating: ./train/10 (new)/cobblestones-293578_640.jpg
#   inflating: ./train/10 (new)/color-4158152_640.jpg
#   inflating: ./train/10 (new)/compass-1850673_640.jpg
#   inflating: ./train/10 (new)/corona-4970836_640.jpg
#   inflating: ./train/10 (new)/crop-2229_640.jpg
#   inflating: ./train/10 (new)/daughter-8318355_640.jpg
#   inflating: ./train/10 (new)/doctor-5707722_640.jpg
#   inflating: ./train/10 (new)/earth-3355931_640.jpg
#   inflating: ./train/10 (new)/elephant-2380009_640.jpg
#   inflating: ./train/10 (new)/entrepreneur-593371_640.jpg
#   inflating: ./train/10 (new)/exzenterhaus-2175925_640.jpg
#   inflating: ./train/10 (new)/fish-2921430_640.jpg
#   inflating: ./train/10 (new)/flowers-1392392_640.jpg
#   inflating: ./train/10 (new)/g427319d4aac27cc17c0f225df5734966545bf24ef56767d55c79ff801fea054966530b0a5592d68b05a9bdbc6c62fc10_640.jpg
#   inflating: ./train/10 (new)/g482351495b890bc17fd5702f0c5feddeee3cf78bdfd61305cf29a144e45a9ed5bdf3463a54deb2db58537db6889f510c_640.jpg
#   inflating: ./train/10 (new)/g75dc4acb4bf82d212b60446b8d9c5b827d18e6a02d312d5df55f8c0328cb9972bfb9518c1fd6552cd8c2271ebd63db30_640.jpg
#   inflating: ./train/10 (new)/g89a7ba0ff91bb938fd2528360d1ab80864832a52bf65d9753af150c68fb9cc8aa85a4433685829fced79ae67b623a0de_640.jpg
#   inflating: ./train/10 (new)/g90a24bb998e877f4e9ec0e3ea83556005bff3aecda7c79156220573ade90f6a34d8b0c49094777b62af2db72a82ab823_640.jpg
#   inflating: ./train/10 (new)/g9b088ea64c7f343c8b0aded228615a1d69f8f80e4ed3f739929271b5ab67e1aa10ea2f28c495314b9431cc804128e58f_640.jpg
#   inflating: ./train/10 (new)/gab5efb99b1f5b1ac18f8f302c793aaa28f5e881eb21d8ae4f7f64f55d3d800a5c77426e67b2e74c5e8d7c1787c13369f_640.jpg
#   inflating: ./train/10 (new)/gdb350dc9cb9d45a3d271811e73ee42bf3262c5e32119dc3ca9ed8d7b4c723a1e987aac278bce15e03c2097e7244d45e6_640.jpg
#   inflating: ./train/10 (new)/ginger-1714196_640.jpg
#   inflating: ./train/10 (new)/giraffe-8310206_640.jpg
#   inflating: ./train/10 (new)/giraffe-plush-toy-77423_640.jpg
#   inflating: ./train/10 (new)/golf-1284011_640.jpg
#   inflating: ./train/10 (new)/grass-1659054_1280.jpg
#   inflating: ./train/10 (new)/hand-3588162_640.jpg
#   inflating: ./train/10 (new)/hanok-2839691_640.jpg
#   inflating: ./train/10 (new)/head-682484_640.jpg
#   inflating: ./train/10 (new)/hills-2836301_640.jpg
#   inflating: ./train/10 (new)/holidays-1283014_640.jpg
#   inflating: ./train/10 (new)/I44MG_20231216_070119.jpg
#   inflating: ./train/10 (new)/IG_20231216_065751.jpg
#   inflating: ./train/10 (new)/IMG-20231216-WA
#   inflating: ./valid/5/IMG_20231217_031816.jpg
#   inflating: ./valid/5/IMG_20231217_031819.jpg
#   inflating: ./valid/5/IMG_20231217_031822.jpg
#   inflating: ./valid/5/IMG_20231217_031824.jpg
#   inflating: ./valid/5/IMG_20231217_031833.jpg
#   inflating: ./valid/5/IMG_20231217_031838.jpg
#   inflating: ./valid/5/IMG_20231217_031843.jpg
#   inflating: ./valid/5/IMG_20231217_031846.jpg
#   inflating: ./valid/5/IMG_20231217_031939.jpg
#   inflating: ./valid/5/IMG_20231217_031944.jpg
#   inflating: ./valid/5/IMG_20231217_031949.jpg
#   inflating: ./valid/5/IMG_20231217_031952.jpg
#   inflating: ./valid/5/IMG_20231217_033324.jpg
#   inflating: ./valid/5/IMG_20231217_033329.jpg
#   inflating: ./valid/5/IMG_20231217_033337.jpg
#   inflating: ./valid/5/IMG_20231217_033350.jpg
#   inflating: ./valid/5/IMG_20231217_033402.jpg
#   inflating: ./valid/5/IMG_20231217_033406.jpg
#   inflating: ./valid/5/IMG_20231217_033503.jpg
#   inflating: ./valid/5/IMG_20231217_033708.jpg
#   inflating: ./valid/5/IMG_20231217_034718.jpg
#   inflating: ./valid/5/IMG_20231217_034750.jpg
#   inflating: ./valid/5/IMG_20231217_034759.jpg
#   inflating: ./valid/5/IMG_20231217_034822.jpg
#   inflating: ./valid/5/IMG_20231217_034828.jpg
#   inflating: ./valid/5/IMG_20231217_034835.jpg
#   inflating: ./valid/5/IMG_20231217_034842.jpg
#   inflating: ./valid/5/IMG_20231217_034944.jpg
#   inflating: ./valid/5/IMG_20231217_035006.jpg
#   inflating: ./valid/5/IMG_20231217_035013.jpg
#   inflating: ./valid/5/IMG_20231217_035908.jpg
#   inflating: ./valid/5/IMG_20231217_040047.jpg
#   inflating: ./valid/5/IMG_20231217_040052.jpg
#    creating: ./valid/50/
#   inflating: ./valid/50/50.13.jpg
#   inflating: ./valid/50/50.17.jpg
#   inflating: ./valid/50/50.23.jpg
#   inflating: ./valid/50/50.27.jpg
#   inflating: ./valid/50/50.42.jpg
#   inflating: ./valid/50/50.47.jpg
#   inflating: ./valid/50/50.50.jpg
#   inflating: ./valid/50/50.52.jpg
#   inflating: ./valid/50/50.54.jpg
#   inflating: ./valid/50/50.56.jpg
#   inflating: ./valid/50/50.58.jpg
#   inflating: ./valid/50/50.6.jpg
#   inflating: ./valid/50/50.60.jpg
#   inflating: ./valid/50/50.69(1).jpg
#   inflating: ./valid/50/50.7.jpg
#   inflating: ./valid/50/50.73.jpg
#   inflating: ./valid/50/50.75.jpg
#   inflating: ./valid/50/50.85.jpg
#   inflating: ./valid/50/50.90.jpg
#   inflating: ./valid/50/50.96.jpg
#   inflating: ./valid/50/IMG-20231217-WA0107.jpg
#   inflating: ./valid/50/IMG-20231217-WA0108.jpg
#   inflating: ./valid/50/IMG-20231217-WA0109.jpg
#   inflating: ./valid/50/IMG-20231217-WA0113.jpg
#   inflating: ./valid/50/IMG-20231217-WA0114.jpg
#   inflating: ./valid/50/IMG_20231217_035146.jpg
#   inflating: ./valid/50/IMG_20231217_035151.jpg
#   inflating: ./valid/50/IMG_20231217_035156.jpg
#   inflating: ./valid/50/IMG_20231217_035200.jpg
# train.zip unzipped into existing ./train folder.

# %%
# Define image size and batch size
IMG_SIZE = 224

'''
# Define train, test, and validation directories
train_dir = '/kaggle/input/egyptian-new-currency-2023/dataset/train'
val_dir = '/kaggle/input/egyptian-new-currency-2023/dataset/valid'
test_dir = '/kaggle/input/egyptian-new-currency-2023/dataset/test'
'''

train_dir = "/content/train"
val_dir = "/content/valid"
test_dir = "/content/test"


class_names = sorted([dir_name for dir_name in os.listdir(train_dir)])

# %%
def read_images_from_folder(folder_path):
    images = []
    labels = []

#     ignore_classes = ['1','10', '100', '50', '20', '200', '5']
    ignore_classes = ['1']
    for class_folder in tqdm(os.listdir(folder_path)):
        # Skip processing images from the specified ignored classes
        if ignore_classes and class_folder.lower() in ignore_classes:
            continue

        class_path = os.path.join(folder_path, class_folder)
        if os.path.isdir(class_path):
            label = class_folder

            for image_file in os.listdir(class_path):
                image_path = os.path.join(class_path, image_file)

                # Reading the image and converting it to a numpy array
                img = Image.open(image_path).convert('RGB').resize((IMG_SIZE, IMG_SIZE))
                img_array = np.array(img, dtype=np.uint8)

                images.append(img_array)
                labels.append(label)

    return np.array(images), np.array(labels)

train_images, train_labels  = read_images_from_folder(train_dir)
valid_images, valid_labels  = read_images_from_folder(val_dir)
test_images, test_labels = read_images_from_folder(test_dir)
# Out:
# 100%|██████████| 10/10 [01:08<00:00,  6.82s/it]
# 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# 100%|██████████| 10/10 [00:08<00:00,  1.13it/s]

# %%
num_classes = len(np.unique(train_labels))
Classes = np.unique(train_labels)
print(f"Classes: {Classes}")
print(f"Number of classes: {num_classes}")
# Out:
# Classes: ['10' '10 (new)' '100' '20' '20 (new)' '200' '5' '50']
# Number of classes: 8

# %%
def image_statistics(images, dataset_name):
    print(f"Dataset: {dataset_name}")
    print(f"Number of images: {len(images)}")

    # Calculate statistics about image shapes
    print(f"Image shapes: {images.shape}")
    print("------------------------------")



# Example usage:
image_statistics(train_images, "Train")
image_statistics(valid_images, "Validation")
image_statistics(test_images, "Test")
# Out:
# Dataset: Train
# Number of images: 2577
# Image shapes: (2577, 224, 224, 3)
# ------------------------------
# Dataset: Validation
# Number of images: 740
# Image shapes: (740, 224, 224, 3)
# ------------------------------
# Dataset: Test
# Number of images: 270
# Image shapes: (270, 224, 224, 3)
# ------------------------------

# %%
plt.figure(figsize=(12, 6))
pd.DataFrame(train_labels).value_counts().sort_index().plot(kind='bar')
plt.title('Training Data Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
# Generate 9 random indices
sample_indices = random.sample(range(len(train_images)), 9)

# Create a 3x3 grid of subplots for plotting the images
plt.figure(figsize=(10, 10))
plt.suptitle("Some Sample Images", fontsize=16)

for i, idx in enumerate(sample_indices):
    plt.subplot(3, 3, i + 1)
    plt.imshow(train_images[idx])  # Assuming images are already in the appropriate format
    plt.title(f"Label: {train_labels[idx]}")
    plt.axis('off')

plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
valid_labels_encoded = label_encoder.transform(valid_labels)
test_labels_encoded = label_encoder.transform(test_labels)

num_classes = len(label_encoder.classes_)

train_labels_one_hot = to_categorical(train_labels_encoded, num_classes=num_classes)
valid_labels_one_hot = to_categorical(valid_labels_encoded, num_classes=num_classes)
test_labels_one_hot = to_categorical(test_labels_encoded, num_classes=num_classes)

# %%
def plot_history(history):
    # Access the training history
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    train_acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    # Create subplots for loss and accuracy
    plt.figure(figsize=(12, 4))
    # Plot training and validation loss
    plt.subplot(1, 2, 1)
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    # Plot training and validation accuracy
    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')
    plt.tight_layout()
    plt.show()

# %%
def predict_class(model, test_images, test_labels, num_images_to_plot=12, num_columns=4):
    # Decode one-hot encoded labels
    test_labels = np.argmax(test_labels_one_hot, axis=1)

    # Choose random indices for testing
    random_indices = np.random.choice(len(test_images), size=num_images_to_plot, replace=False)

    # Calculate the number of rows needed based on the number of images and columns
    num_rows = int(np.ceil(len(random_indices) / num_columns))

    # Create a subplot with the specified number of rows and columns
    fig, axes = plt.subplots(num_rows, num_columns, figsize=(15, 3*num_rows))

    # Loop through the selected indices for prediction and plotting
    for i, ax in zip(random_indices, axes.flatten()):
        # Get the image and label
        image = test_images[i]
        label = test_labels[i]

        # Reshape the image to match the input shape expected by the model
        image = np.expand_dims(image, axis=0)

        # Predict the image using the loaded model
        prediction = model.predict(image)

        # Get the predicted label
        predicted_label = np.argmax(prediction)

        # Plot the image
        ax.imshow(image.squeeze())  # Squeeze to remove the singleton dimension
        ax.set_title(f"Actual Label: {label}\n Predicted Label: {predicted_label}")

    # Adjust layout for better spacing
    plt.tight_layout()
    plt.show()

# %%
# Define the number of epochs
NUM_CLASSES = num_classes
num_epochs = 5  #200
batch_size = 32

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=40, verbose=2, restore_best_weights=True)

# %%
# Build the deep learning model
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# model.summary()
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Start training the model
history = model.fit(
    train_images,
    train_labels_one_hot,
    epochs=num_epochs,
    batch_size=batch_size,
    validation_data=(valid_images, valid_labels_one_hot),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/5
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 357s 4s/step - accuracy: 0.4772 - loss: 1.6899 - val_accuracy: 0.4959 - val_loss: 3.9852
# Epoch 2/5
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 371s 4s/step - accuracy: 0.4991 - loss: 1.4703 - val_accuracy: 0.5041 - val_loss: 3.3735
# Epoch 3/5
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 362s 4s/step - accuracy: 0.4683 - loss: 1.9190 - val_accuracy: 0.3230 - val_loss: 3.4389
# Epoch 4/5
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 343s 4s/step - accuracy: 0.5085 - loss: 1.6180 - val_accuracy: 0.4865 - val_loss: 5.1867
# Epoch 5/5
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 364s 4s/step - accuracy: 0.4985 - loss: 1.8069 - val_accuracy: 0.5000 - val_loss: 2.7352
# Restoring model weights from the end of the best epoch: 5.

# %%
model.evaluate(test_images, test_labels_one_hot)

# %%
predict_class(model, test_images, test_labels_one_hot)

# save model
model.save('model-0.h5')
